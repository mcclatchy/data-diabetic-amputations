# %%
import os
import json
import censusdata
import subprocess
import pandas as pd
from uszipcode import SearchEngine

# This is the location of my Mapshaper binary
MAPSHAPER = os.path.join(os.path.expanduser('~'), "node_modules/mapshaper/bin/mapshaper")
DATA_DIRECTORY = os.path.join(os.getcwd(), "data")

pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### (1) Mapping Zip Codes to State FIPS Codes
# Source: https://www2.census.gov/geo/docs/maps-data/data/rel/zcta_place_rel_10.txt

# %%
zipcode_search = SearchEngine(simple_or_comprehensive=SearchEngine.SimpleOrComprehensiveArgEnum.simple)
def get_state_abbreviation_from_zcta(zcta, search_engine=zipcode_search):
    zipcode_data = search_engine.by_zipcode(zcta)
    if zipcode_data:
        return zipcode_data.state
    else:
        return None

# %% [markdown]
# ### (2) Mapping U.S. State Names, U.S. State Abbreviations and FIPS Codes
# Source: https://gist.github.com/rogerallen/1583593

# %%
with open(os.path.join(DATA_DIRECTORY, "us_state_to_abbrev.json")) as f:
    us_state_to_abbrev = json.loads(f.read())

abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))
    
with open(os.path.join(DATA_DIRECTORY, "us_state_abbrev_to_fips.json")) as f:
    us_state_abbrev_to_fips = json.loads(f.read())

fips_to_us_state_abbrev = dict(map(reversed, us_state_abbrev_to_fips.items()))

# %% [markdown]
# ### (3) Read & Format Diabetic Amputation Data by State
#
# The State Media Co. filed open records requests to gain hospital discharge data from southeastern states from 2016 to 2020. The data consisted of 76 procedural codes for nontraumatic lower extremity amputations for diabetic patients, broken down by each patient’s ZIP code of residence. Four southeastern states (Louisiana, Arkansas, North Carolina and Tennessee) either did not have data or would not provide it. ZIP code populations, according to 5-year averages from the U.S. Census Bureau, were then divided by the number of amputations for each ZIP code for each year to create a rate. For privacy reasons, some states suppressed amputation data for certain ZIP codes when there were fewer than five procedures. The newspaper then took the population size of 29203 and compared it with ZIP codes the same size or larger in South Carolina, Georgia, Alabama and Mississippi.

# %%
def add_empty_rows_to_df(df, years=[2016, 2017, 2018, 2019, 2020]):
    zipcodes_vec = []
    years_vec = []
    amputations_vec = []

    for zipcode in df.ZIP.unique():
        df_years = df[df.ZIP == zipcode].YEAR
        empty_years = list(set(years) - set(df_years))

        for year in empty_years:
            zipcodes_vec.append(zipcode)
            years_vec.append(year)
            amputations_vec.append(0)
    
    empty_df = pd.DataFrame({
        'ZIP': zipcodes_vec,
        'YEAR': years_vec,
        'AMPUTATIONS': amputations_vec
    })
    
    return pd.concat([df, empty_df])

def format_amputations_df(df, state_fips, us_state_abbrev_to_fips):
    # Alabama's amputations column neeeds to be summed by zipcode
    # We will aggregate these rows into unique zipcode rows
    df['AMPUTATIONS'] = [value if value != "*" else 0 for value in df['AMPUTATIONS']]
    df = df.groupby(['ZIP', 'YEAR'])['AMPUTATIONS'].sum().reset_index()

    # Add empty years (i.e. 0 amputations)
    df = add_empty_rows_to_df(df)
    
    # Each file contains patient zip codes outside of their own state
    # For this investigation, we will be dropping these items from each df
    zipcodes = df['ZIP']
    state_abbreviations = [get_state_abbreviation_from_zcta(zipcode) for zipcode in zipcodes]
    df['State'] = state_abbreviations
    df['State FIPS'] = [us_state_abbrev_to_fips[abbrev] if abbrev in us_state_abbrev_to_fips else None for abbrev in state_abbreviations]
    df = df[df['State FIPS'] == state_fips].reset_index(drop=True)
    
    return df

state_abbreviations = ['AL', 'FL', 'GA', 'KY', 'MS', 'SC', 'VA', 'WV']
state_fips_codes = [us_state_abbrev_to_fips[abbrev] for abbrev in state_abbreviations]
amputations_dfs = []

for state_abbreviation in state_abbreviations:
    filename = "Diabetic Amputations Raw Data - {0}.csv".format(state_abbreviation)
    filepath = os.path.join(DATA_DIRECTORY, filename)
    df = pd.read_csv(filepath, dtype={'ZIP': str})
    state_fips = us_state_abbrev_to_fips[state_abbreviation]
    formatted_df = format_amputations_df(df, state_fips, us_state_abbrev_to_fips)
    amputations_dfs.append(formatted_df)
    
amputations_df = pd.concat(amputations_dfs).sort_values(by=['State', 'ZIP', 'YEAR'])

# %%
amputations_df[amputations_df.ZIP=='29203']
# Out:
#        ZIP  YEAR AMPUTATIONS State State FIPS
# 207  29203  2016          46    SC         45
# 208  29203  2017          49    SC         45
# 209  29203  2018          35    SC         45
# 210  29203  2019          38    SC         45
# 211  29203  2020          31    SC         45

# %% [markdown]
# ### (4) Get Population Data by Year
# The Census data we used comes from the ACS 5-year estimates at the ZCTA level (approximate polygons for ZIP codes, which are really delivery routes). We used the 5-year averages since a ZIP code is a very small geographic unit for ACS survey methods, and there simply isn’t high enough precision to get reliable estimates from the 1-year ACS or 3-year ACS datasets.

# %%
# https://api.census.gov/data/2010/acs/acs5/variables.html
# B01003_001E - Estimate!!Total - TOTAL POPULATION
# API - https://api.census.gov/data/2016/acs/acs5?get=NAME,ZCTA,B01003_001E&for=zip+code+tabulation+area:*&in=state:12
years = [2016, 2017, 2018, 2019, 2020]
census_product = 'acs5'
fips_string = ','.join(state_fips_codes)
code_string = 'B01003_001E'
year_zcta_population_dict = {}

for year in years:
    # API didn't seem to support the "in" query for specifying states in 2020
    if year == 2020:
        population_table = censusdata.download(census_product, year,
           censusdata.censusgeo([
               ('zip%20code%20tabulation%20area', '*')
           ]),['ZCTA',code_string])
    else:
        population_table = censusdata.download(census_product, year,
           censusdata.censusgeo([
               ('state', fips_string),
               ('zip%20code%20tabulation%20area', '*')
           ]),['ZCTA',code_string])
    zcta_population_dict = dict(zip(population_table.ZCTA, population_table.B01003_001E))
    year_zcta_population_dict[year] = zcta_population_dict
    print("Finished processing {0} {1}".format(census_product, year))
# Out:
# Finished processing acs5 2016
# Finished processing acs5 2017
# Finished processing acs5 2018
# Finished processing acs5 2019
# Finished processing acs5 2020

# %%
# Get population from the back up 2010 Census
# There were many ZIP codes with no population, so this was a double check
# to see if that data were erroneous or retrievable (albeit through an old decennial)
census_2010_population = censusdata.download('sf1', 2010,
       censusdata.censusgeo([
           ('state', fips_string),
           ('zip code tabulation area (or part)', '*')
       ]),['ZCTA5','P001001'])
census_2010_zcta_population_dict = dict(zip(census_2010_population.ZCTA5, census_2010_population.P001001))

# %% [markdown]
# ### (5) Add Population Data to Amputations Data
# Similarly, we used 5-year averages as more reliable estimates for the amputation rate of a given ZIP code. We also calculated these rates per 10K residents and per 40K residents.

# %%
population_vec = []

for i, row in amputations_df.iterrows():
    zcta = int(row.ZIP)
    year = row.YEAR
    amputations = row.AMPUTATIONS
    if zcta not in year_zcta_population_dict[year]:
        in_2010_census = zcta in census_2010_zcta_population_dict
#         print("WARNING: No population found for {0} in {1} {2}".format(zcta, year, in_2010_census))
        if in_2010_census:
            print("FOUND {0} population in Decennial Census of 2010".format(zcta))
            population = census_2010_zcta_population_dict[zcta]
        else:
            population = 0
    else:
        population = year_zcta_population_dict[year][zcta]
    population_vec.append(population)

amputations_df['POPULATION'] = population_vec
amputations_df['AMPUTATIONS_PER_10K'] = [10000 * float(amputations_df.AMPUTATIONS.iloc[i]) / float(amputations_df.POPULATION.iloc[i]) if amputations_df.POPULATION.iloc[i] != 0 else None  for i in range(len(amputations_df))]
amputations_df['AMPUTATIONS_PER_40K'] = [40000 * float(amputations_df.AMPUTATIONS.iloc[i]) / float(amputations_df.POPULATION.iloc[i]) if amputations_df.POPULATION.iloc[i] != 0 else None  for i in range(len(amputations_df))]

avg_populations_dict = amputations_df.groupby(["ZIP"])['POPULATION'].mean().to_dict()
amputations_df['AVERAGE POPULATION (2016-2020)'] = [avg_populations_dict[z] for z in amputations_df.ZIP]

# %%
amputations_df
# Out:
#         ZIP  YEAR AMPUTATIONS State State FIPS  POPULATION  \
# 1763  35004  2016           0    AL         01       10418
# 0     35004  2017           3    AL         01       11167
# 1     35004  2018           3    AL         01       11762
# 1764  35004  2019           0    AL         01       12045
# 2     35004  2020           2    AL         01       11944
# ...     ...   ...         ...   ...        ...         ...
# 1552  26852  2016           0    WV         54         782
# 2727  26852  2017           0    WV         54         897
# 2728  26852  2018           0    WV         54         809
# 1553  26852  2019           0    WV         54         742
# 2729  26852  2020           0    WV         54         843
#
#       AMPUTATIONS_PER_10K  AMPUTATIONS_PER_40K  AVERAGE POPULATION (2016-2020)
# 1763             0.000000             0.000000                         11467.2
# 0                2.686487            10.745948                         11467.2
# 1                2.550587            10.202347                         11467.2
# 1764             0.000000             0.000000                         11467.2
# 2                1.674481             6.697924                         11467.2
# ...                   ...                  ...                             ...
# 1552             0.000000             0.000000                           814.6
# 2727             0.000000             0.000000                           814.6
# 2728             0.000000             0.000000                           814.6
# 1553             0.000000             0.000000                           814.6
# 2729             0.000000             0.000000                           814.6
#
# [25725 rows x 9 columns]

# %% [markdown]
# ### (6) Get Insurance Data by Year
# ```
# S2701_C01_001E - Total!!Estimate!!Civilian noninstitutionalized population
# S2701_C04_001E - Uninsured!!Estimate!!Civilian noninstitutionalized population
# S2701_C05_001E - Percent Uninsured!!Estimate!!Civilian noninstitutionalized population
# ```

# %%
# https://api.census.gov/data/2015/acs/acs5/subject/groups/S2701.html
# S2701_C01_001E - Total!!Estimate!!Civilian noninstitutionalized population
# S2701_C04_001E - Uninsured!!Estimate!!Civilian noninstitutionalized population
# S2701_C05_001E - Percent Uninsured!!Estimate!!Civilian noninstitutionalized population
# https://api.census.gov/data/2015/acs/acs5/subject/?get=NAME,ZCTA,S2701_C05_001E&for=zip+code+tabulation+area:*&in=state:12


year_zcta_insurance_dict = {}

for year in years:
    insurance_table = censusdata.download('acs5/subject', year,
           censusdata.censusgeo([
               ('zip code tabulation area', '*')
           ]),['ZCTA','S2701_C04_001E', 'S2701_C01_001E', 'S2701_C05_001E'])
    zcta_insurance_dict = {}
    for i, zcta in enumerate(list(insurance_table.ZCTA)):
        zcta_insurance_dict[zcta] = {
            "NONINSTITUTIONALIZED POPULATION": insurance_table.S2701_C01_001E.iloc[i],
            "UNINSURED POPULATION (NON-I)": insurance_table.S2701_C04_001E.iloc[i],
            "UNINSURED PERCENTAGE (NON-I)": insurance_table.S2701_C05_001E.iloc[i]
        }
    year_zcta_insurance_dict[year] = zcta_insurance_dict
    print("Finished processing {0} {1}".format('acs5/subject', year))
# Out:
# Finished processing acs5/subject 2016
# Finished processing acs5/subject 2017
# Finished processing acs5/subject 2018
# Finished processing acs5/subject 2019
# Finished processing acs5/subject 2020

# %% [markdown]
# ### (7) Add Insurance Data to Amputations Data
# Merged insurance data with amputation data.

# %%
noninstitutionalized_vec = []
uninsured_pop_vec = []
uninsured_percentage_vec = []

for i, row in amputations_df.iterrows():
    zcta = int(row.ZIP)
    year = row.YEAR
    if zcta not in year_zcta_insurance_dict[year]:
        noninstitutionalized_vec.append(None)
        uninsured_pop_vec.append(None)
        uninsured_percentage_vec.append(None)
    elif year_zcta_insurance_dict[year][zcta]['UNINSURED PERCENTAGE (NON-I)'] == -666666666:
        noninstitutionalized_vec.append(None)
        uninsured_pop_vec.append(None)
        uninsured_percentage_vec.append(None)
    else: 
        noninstitutionalized_vec.append(year_zcta_insurance_dict[year][zcta]['NONINSTITUTIONALIZED POPULATION'])
        uninsured_pop_vec.append(year_zcta_insurance_dict[year][zcta]['UNINSURED POPULATION (NON-I)'])
        uninsured_percentage_vec.append(year_zcta_insurance_dict[year][zcta]['UNINSURED PERCENTAGE (NON-I)'])

    
amputations_df['NONINSTITUTIONALIZED POPULATION'] = noninstitutionalized_vec
amputations_df['UNINSURED POPULATION (NON-I)'] = uninsured_pop_vec
amputations_df['UNINSURED PERCENTAGE (NON-I)'] = uninsured_percentage_vec

# %%
amputations_df
# Out:
#         ZIP  YEAR AMPUTATIONS State State FIPS  POPULATION  \
# 1763  35004  2016           0    AL         01       10418
# 0     35004  2017           3    AL         01       11167
# 1     35004  2018           3    AL         01       11762
# 1764  35004  2019           0    AL         01       12045
# 2     35004  2020           2    AL         01       11944
# ...     ...   ...         ...   ...        ...         ...
# 1552  26852  2016           0    WV         54         782
# 2727  26852  2017           0    WV         54         897
# 2728  26852  2018           0    WV         54         809
# 1553  26852  2019           0    WV         54         742
# 2729  26852  2020           0    WV         54         843
#
#       AMPUTATIONS_PER_10K  AMPUTATIONS_PER_40K  \
# 1763             0.000000             0.000000
# 0                2.686487            10.745948
# 1                2.550587            10.202347
# 1764             0.000000             0.000000
# 2                1.674481             6.697924
# ...                   ...                  ...
# 1552             0.000000             0.000000
# 2727             0.000000             0.000000
# 2728             0.000000             0.000000
# 1553             0.000000             0.000000
# 2729             0.000000             0.000000
#
#       AVERAGE POPULATION (2016-2020)  NONINSTITUTIONALIZED POPULATION  \
# 1763                         11467.2                          10400.0
# 0                            11467.2                          11146.0
# 1                            11467.2                          11742.0
# 1764                         11467.2                          12019.0
# 2                            11467.2                          11912.0
# ...                              ...                              ...
# 1552                           814.6                            782.0
# 2727                           814.6                            897.0
# 2728                           814.6                            809.0
# 1553                           814.6                            742.0
# 2729                           814.6                            843.0
#
#       UNINSURED POPULATION (NON-I)  UNINSURED PERCENTAGE (NON-I)
# 1763                         344.0                           3.3
# 0                            559.0                           5.0
# 1                            733.0                           6.2
# 1764                         830.0                           6.9
# 2                            933.0                           7.8
# ...                            ...                           ...
# 1552                          13.0                           1.7
# 2727                          83.0                           9.3
# 2728                          66.0                           8.2
# 1553                          91.0                          12.3
# 2729                          60.0                           7.1
#
# [25725 rows x 12 columns]

# %% [markdown]
# ### (8) Extrapolating VA's Q1-Q3 2020 Data
# Virginia's dataset does not include 2016 and only includes Q1-Q3 (inclusive) in 2020. We don't have access to the monthly/daily distribution of amputations, so here we are extrapolating linearly to impute values for Q4, then rounding to whole numbers for the final extrapolated total for VA 2020 amputation data.

# %%
amputations_df.loc[
    amputations_df.State == 'VA', 'AMPUTATIONS'
] = amputations_df.loc[amputations_df.State == 'VA', 'AMPUTATIONS'].apply(lambda x: round(int(x)/.75))

# %%
amputations_df = amputations_df.drop(['State FIPS', 'UNINSURED PERCENTAGE (NON-I)'], 1)
# Out:
# /var/folders/1m/gs67qnm13_zdcfgmdqmjy_sh0000gp/T/ipykernel_54145/1500814753.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   amputations_df = amputations_df.drop(['State FIPS', 'UNINSURED PERCENTAGE (NON-I)'], 1)

# %%
amputations_df.to_csv(os.path.join(DATA_DIRECTORY, 'amputations.csv'),index=False)

# %% [markdown]
# ### (9) Calculating Averages and Rankings
#
# This output looks at ZIP codes above 39000 people across Mississippi, Alabama, Georgia and South Carolina from 2016-2020. The purpose is to find rankings and average amputation rates across these years.
#
# #### Methodology
# The authors' chosen methodology was to compare population-wide diabetic amputation rates for ZIP codes **the same size or larger** than the point of reference of 29203 (whose 5-year average population is ~39.9K). However, there are many other options for methods of comparison.
#
# From a data similarity perspective, it is likely more appropriate to compare 29203 to a range of populations, both above and below its own population of 39K: for instance a range between 20K and 60K. If we followed this methodology, 29203's amputation rate would have the 11th-worst amputation rate instead of 1st-worst over the 5-year span (when including MS, AL, GA and SC).
#
# If we also add the states of Kentucky, West Virginia and Virginia (whose data was also collected by The State Media Co. - Florida was also collected, though there's a chance the methodology may count individual amputation procedures rather than number of individuals who received amputations) into this methodology, 29203 would rank 34th-worst. Separately, it may make sense to compare ZIP codes with similar population densities amongst ZIP codes instead.
#
# From a data metric perspective, a population-wide diabetic amputation rate is not the best metric for care specific to people with diabetes. If 100% of the population of a 10,000 person town had diabetes, and 10 people recieved amputations, the population-wide amputation rate would be **10 per 10K residents**. The diabetic-population amputation rate would be **10 per 10K diabetics**, since everyone has diabetes.
#
# Now, if 10% of the population of 10,000 person town had diabetes (i.e. 1000 people), and 10 people still received amputations, the population-wide amputation rate would still be **10 per 10K residents**. However, the diabetic-population amputation rate would now be **100 per 10K diabetics%** (5/10). The second group of diabetics are receiving significantly worse care, with much worse outcomes. This metric would better encapsulate a comparison of diabetic amputations across ZIP codes as well.

# %%
amputations_df['AMPUTATIONS'] = amputations_df['AMPUTATIONS'].astype(int)
population_filter = 39000
state_filter = ['MS', 'AL', 'GA', 'SC']

# %%
filtered_df = amputations_df[
    (amputations_df['AVERAGE POPULATION (2016-2020)'] > population_filter) &
    (amputations_df['State'].isin(state_filter))
]
print("Num filtered ZIP codes: {0}".format(len(filtered_df.ZIP.unique())))
# Out:
# Num filtered ZIP codes: 120

# %%
years = [2016, 2017, 2018, 2019, 2020]

filtered_cols = ['ZIP', 'State', 'AVERAGE POPULATION (2016-2020)']
filtered_zipcodes_states = filtered_df[filtered_cols].drop_duplicates().sort_values(by=['ZIP']).reset_index(drop=True)
filtered_amputations_by_year = filtered_df.pivot(index='ZIP', columns='YEAR', values='AMPUTATIONS').reset_index()
filtered_population_by_year = filtered_df.pivot(index='ZIP', columns='YEAR', values='POPULATION').reset_index()
filtered_amputation_rate_by_year = filtered_amputations_by_year[years] / filtered_population_by_year[years] * 10000
filtered_amputation_rank_by_year = filtered_amputation_rate_by_year.rank(ascending=False).astype(int)

# %%
# Avg. Amputations Per 10K (2016-2020)

avg_amputations_per_10K = []

for i, row in filtered_zipcodes_states.iterrows():
    
    # We suspect Alabama's data for 2016 and 2017 is undercounted, so we are calculating
    # the state's averages only over 2018, 2019 and 2020
    if row.State == 'AL':
        col_indices = [3,4,5]
    elif row.State == 'VA':
        # Similarly Virginia's methodology is only valid from 2017-2020
        col_indices = [2,3,4,5]
    else:
        col_indices = [1,2,3,4,5]
    
    sum_amputations = filtered_amputations_by_year.iloc[i, col_indices].sum()
    sum_population = filtered_population_by_year.iloc[i, col_indices].sum()
    avg_amputations = round(sum_amputations / sum_population * 10000, 2)
    avg_amputations_per_10K.append(avg_amputations)

avg_amputations_per_10K_df = pd.DataFrame({
    'Avg. Amputations Per 10K (2016-2020)': avg_amputations_per_10K
})

# %%
filtered_ranks_rates_df = pd.concat([
    filtered_zipcodes_states,
    filtered_amputation_rank_by_year,
    avg_amputations_per_10K_df
], axis = 1)

# %%
filtered_ranks_rates_df = filtered_ranks_rates_df.sort_values(
    by=['Avg. Amputations Per 10K (2016-2020)'], ascending=[False]
)

# %%
def get_city_from_zipcode(x):
    city = SearchEngine().by_zipcode(x).major_city
    return city if city else 'None'

cities = [get_city_from_zipcode(zipcode) for zipcode in filtered_ranks_rates_df['ZIP']]
filtered_ranks_rates_df['City'] = cities

rankingData = []

for i, row in filtered_ranks_rates_df.iterrows():
    rankingData.append(
        {
            "zip": str(row['ZIP']),
            "city": row['City'],
            "state": row['State'],
            "state_name": abbrev_to_us_state[row['State']],
            "rank_2016": row[2016],
            "rank_2017": row[2017],
            "rank_2018": row[2018],
            "rank_2019": row[2019],
            "rank_2020": row[2020],
            "amputation_rate": row['Avg. Amputations Per 10K (2016-2020)'],
            "pop": int(row['AVERAGE POPULATION (2016-2020)'])
        }
    )

# %%
with open(os.path.join(DATA_DIRECTORY, 'table_rates_rankings.json'), 'w') as f:
    json.dump(rankingData, f)

# %% [markdown]
# ### (10) Finding population densities
#
# We need to add population densities and a number of other features into the Census dataset of zipcodes. And we need to remove other fields that will only take up space. The Census ZCTA shapefile isn't broken down by state (likely because there are many ZIP codes whose area intersects multiple states). So the first few steps are an attempt to geographically filter the zipcodes using Census state shapefiles. For these steps, you need to install [Mapshaper](https://github.com/mbloch/mapshaper)

# %%
# Manually download and unzip Zip Code Tabulation Area (ZCTA) shapefile from the Census into your DATA_DIRECTORY
# https://www2.census.gov/geo/tiger/TIGER2021/ZCTA520/tl_2021_us_zcta520.zip

states_census_filepath = os.path.join(DATA_DIRECTORY, 'tl_2021_us_state', 'tl_2021_us_state.shp')
deep_south_filepath = os.path.join(DATA_DIRECTORY, 'deep_south.json')
filter_expression = '"28,01,13,45".indexOf(STATEFP) > -1'

subprocess.run([MAPSHAPER, states_census_filepath, "-filter", filter_expression, "-o", deep_south_filepath])
# Out:
# [filter] Retained 4 of 56 features
# [o] Wrote /Users/davidnewcomb/notebooks/data/diabetic_amputations/deep_south.json
# CompletedProcess(args=['/Users/davidnewcomb/node_modules/mapshaper/bin/mapshaper', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/tl_2021_us_state/tl_2021_us_state.shp', '-filter', '"28,01,13,45".indexOf(STATEFP) > -1', '-o', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/deep_south.json'], returncode=0)

# %%
zcta_census_filepath = os.path.join(DATA_DIRECTORY, 'tl_2021_us_zcta520', 'tl_2021_us_zcta520.shp')
zcta_deep_south_filepath = os.path.join(DATA_DIRECTORY, 'zcta_deep_south.json')

subprocess.run([MAPSHAPER, zcta_census_filepath, "-clip", deep_south_filepath, "-o", zcta_deep_south_filepath])
# Out:
# [o] Wrote /Users/davidnewcomb/notebooks/data/diabetic_amputations/zcta_deep_south.json
# CompletedProcess(args=['/Users/davidnewcomb/node_modules/mapshaper/bin/mapshaper', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/tl_2021_us_zcta520/tl_2021_us_zcta520.shp', '-clip', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/deep_south.json', '-o', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/zcta_deep_south.json'], returncode=0)

# %%
zcta_filepath = os.path.join(DATA_DIRECTORY, 'zipcodes.json')

subprocess.run([MAPSHAPER, zcta_deep_south_filepath, "-simplify", "12%", "-o", "format=topojson", zcta_filepath])
# Out:
# [simplify] Repaired 172 intersections
# [o] Wrote /Users/davidnewcomb/notebooks/data/diabetic_amputations/zipcodes.json
# CompletedProcess(args=['/Users/davidnewcomb/node_modules/mapshaper/bin/mapshaper', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/zcta_deep_south.json', '-simplify', '12%', '-o', 'format=topojson', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/zipcodes.json'], returncode=0)

# %% [markdown]
# Now that we have filtered ZCTA shapes, we can focus on getting population densities, amputation rates, and other information added into the `zipcodes.json` file.

# %%
deep_south_df = amputations_df[amputations_df.State.isin(['SC', 'AL', 'MS', 'GA'])].reset_index(drop=True)
deep_south_df['AMPUTATIONS'] = deep_south_df['AMPUTATIONS'].astype(int)

deep_south_avg_populations_df = deep_south_df.groupby(["ZIP"])['POPULATION'].mean()
deep_south_states_df = deep_south_df.groupby(["ZIP"])['State'].first()
deep_south_amputations_df = deep_south_df.groupby(["ZIP"])['AMPUTATIONS'].sum()
deep_south_amputation_rates_df = deep_south_amputations_df / deep_south_df.groupby(["ZIP"])['POPULATION'].sum()*10000

# %% [markdown]
# #### Methodology
#
# Alabama's dataset was more accurately reported for 2018-2020, and Virginia's was more accurately reported for 2017-2020. For the overall statistics on number of amputations and amputation rate per 10K residents, these numbers are aggregated/averaged over 3 and 4 years, respectively.

# %%
AL_df = deep_south_df[(deep_south_df['YEAR'].isin([2018, 2019, 2020])) & (deep_south_df['State'] == 'AL')]
AL_amputations_df = AL_df.groupby(["ZIP"])['AMPUTATIONS'].sum()
AL_amputation_rates_df = AL_amputations_df / AL_df.groupby(["ZIP"])['POPULATION'].sum()*10000

VA_df = deep_south_df[(deep_south_df['YEAR'].isin([2017, 2018, 2019, 2020])) & (deep_south_df['State'] == 'VA')]
VA_amputations_df = VA_df.groupby(["ZIP"])['AMPUTATIONS'].sum()
VA_amputation_rates_df = VA_amputations_df / VA_df.groupby(["ZIP"])['POPULATION'].sum()*10000

# %%
with open(zcta_filepath) as f:
    zipcodes_json = json.loads(f.read())
    
final_data = {
    'ZIP': [],
    'POPDENSITY': [],
    'POPULATION_5_YR_AVG': [],
    'AMPUTATION_RATE_5_YR_AVG_PER_10K': [],
    'AMPUTATIONS': [],
    'STATE': []
}
fields_to_remove = [
    'GEOID20', 'CLASSFP20', 'MTFCC20', 'FUNCSTAT20', 'ALAND20', 'AWATER20', 'INTPTLAT20', 'INTPTLON20'
]

for z in zipcodes_json['objects']['zcta_deep_south']['geometries']:
    zipcode_code = z['properties']['ZCTA5CE20']
    
    # Get land in square miles
    zipcode_land = z['properties']['ALAND20'] * 3.86102e-7
    
    if zipcode_code in deep_south_avg_populations_df:
        zipcode_state = deep_south_states_df[zipcode_code]
        zipcode_population = deep_south_avg_populations_df[zipcode_code]
        
        if zipcode_population > 0:
            zipcode_density = round(float(zipcode_population) / float(zipcode_land) , 2)

            if zipcode_state == 'AL':
                zipcode_amputation_rate_avg = AL_amputation_rates_df[zipcode_code]
                zipcode_amputations = AL_amputations_df[zipcode_code]
            else:
                zipcode_amputation_rate_avg = deep_south_amputation_rates_df[zipcode_code]
                zipcode_amputations = deep_south_amputations_df[zipcode_code]
            
            z['properties']['POPDENSITY'] = zipcode_density
            z['properties']['POPULATION_5_YR_AVG'] = zipcode_population
            z['properties']['AMPUTATION_RATE_5_YR_AVG_PER_10K'] = round(zipcode_amputation_rate_avg, 2)
            z['properties']['AMPUTATIONS'] = zipcode_amputations.astype(str)
            z['properties']['STATE'] = zipcode_state

            final_data['ZIP'].append(zipcode_code)
            final_data['POPDENSITY'].append(zipcode_density)
            final_data['POPULATION_5_YR_AVG'].append(zipcode_population)
            final_data['AMPUTATION_RATE_5_YR_AVG_PER_10K'].append(round(zipcode_amputation_rate_avg, 2))
            final_data['AMPUTATIONS'].append(zipcode_amputations)
            final_data['STATE'].append(zipcode_state)
        else:
            z['properties']['POPDENSITY'] = 0
            z['properties']['POPULATION_5_YR_AVG'] = 0
            z['properties']['AMPUTATION_RATE_5_YR_AVG_PER_10K'] = 0
            z['properties']['AMPUTATIONS'] = 0
            z['properties']['STATE'] = deep_south_states_df[zipcode_code]
    else:
        z['properties']['POPDENSITY'] = 0
        z['properties']['POPULATION_5_YR_AVG'] = 0
        z['properties']['AMPUTATION_RATE_5_YR_AVG_PER_10K'] = 0
        z['properties']['AMPUTATIONS'] = 0
        
        if zipcode_code in deep_south_states_df:
            z['properties']['STATE'] = deep_south_states_df[zipcode_code]
        elif zipcode_code.startswith('30') or zipcode_code.startswith('31'):
            z['properties']['STATE'] = 'GA'
        elif zipcode_code.startswith('35') or zipcode_code.startswith('36'):
            z['properties']['STATE'] = 'AL'
        elif zipcode_code.startswith('38') or zipcode_code.startswith('39'):
            z['properties']['STATE'] = 'MS'
        elif zipcode_code.startswith('29') or zipcode_code.startswith('39'):
            z['properties']['STATE'] = 'SC'
        else:
            print(zipcode_code)
    
    for field in fields_to_remove:
        if field in z['properties']:
            del z['properties'][field]

final_df = pd.DataFrame(final_data)

# %%
with open(os.path.join(DATA_DIRECTORY, 'zipcodes_final.json'), 'w') as f:
    json.dump(zipcodes_json, f)

# %% [markdown]
# For mapping purposes it can help to simplify the geographies, resulting in a smaller file.

# %%
zipcodes_filepath = os.path.join(DATA_DIRECTORY, 'zipcodes_final.json')
zipcodes_condensed_filepath = os.path.join(DATA_DIRECTORY, 'zipcodes_condensed.json')

subprocess.run([MAPSHAPER, zipcodes_filepath, "-simplify", "70%", "-o", zipcodes_condensed_filepath])
# Out:
# [simplify] Repaired 166 intersections; 16 intersections could not be repaired
# [o] Wrote /Users/davidnewcomb/notebooks/data/diabetic_amputations/zipcodes_condensed.json
# CompletedProcess(args=['/Users/davidnewcomb/node_modules/mapshaper/bin/mapshaper', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/zipcodes_final.json', '-simplify', '70%', '-o', '/Users/davidnewcomb/notebooks/data/diabetic_amputations/zipcodes_condensed.json'], returncode=0)

# %% [markdown]
# ### (11) Looking into Poverty Data
#
# Ultimately, for the article we used Low-to-Moderate Income numbers by census tract, found at this [HUD map](https://hudgis-hud.opendata.arcgis.com/datasets/HUD::low-to-moderate-income-population-by-tract/explore?filters=eyJTVEFURSI6WyI0NSJdLCJDT1VOVFkiOlsiMDc5IiwiMDYzIiwiMDE3Il19&location=34.004900%2C-81.118087%2C9.97) (whose data is downloadable). This section gathers poverty data for Lexington County (FIPS: 063) and Richland County (FIPS: 079) in South Carolina.

# %%
# FIPS Codes
# 063 - Lexington County, SC
# 079 - Richland County, SC

# ACS5 Variables
# B06012_002E - Population
# B06012_002E - Estimate!!Total!!Below 100 percent of the poverty level

poverty_table = censusdata.download('acs5', 2019,
   censusdata.censusgeo([
       ('state', '45'),
       ('county', '063,079'),
       ('tract', '*')
   ]),['TRACT','B01003_001E', 'B06012_001E', 'B06012_002E', 'B06012_003E', 'B06012_004E'])

# %%
tract_ids = [
    "000400",
    "000300",
    "000100",
    "001000",
    "010200",
    "010102",
    "011404",
    "010703",
    "010702",
    "010900",
    "010804",
    "000600",
    "000900",
    "000500",
    "010600",
    "010502",
    "010701",
    "000700",
    "010501",
    "000200",
    "010805",
    "010806"
]

poverty_rates = []
for tract_id in tract_ids:
    total_pop = poverty_table[poverty_table.TRACT == int(tract_id)]['B06012_001E']
    poverty_pop = poverty_table[poverty_table.TRACT == int(tract_id)]['B06012_002E']
    poverty_rate = round(float(int(poverty_pop)) / float(int(total_pop)), 4)
    poverty_rates.append(poverty_rate)
    
dict(zip(tract_ids, poverty_rates))
# Out:
# {'000400': 0.2268,
#  '000300': 0.4683,
#  '000100': 0.278,
#  '001000': 0.438,
#  '010200': 0.1466,
#  '010102': 0.1702,
#  '011404': 0.1908,
#  '010703': 0.4105,
#  '010702': 0.2626,
#  '010900': 0.5144,
#  '010804': 0.3386,
#  '000600': 0.1474,
#  '000900': 0.579,
#  '000500': 0.4557,
#  '010600': 0.3943,
#  '010502': 0.488,
#  '010701': 0.1924,
#  '000700': 0.1924,
#  '010501': 0.1599,
#  '000200': 0.2671,
#  '010805': 0.199,
#  '010806': 0.8177}

# %%
poverty_table
# Out:
#                                                      TRACT  B01003_001E  \
# Census Tract 25, Richland County, South Carolin...    2500         3743
# Census Tract 26.02, Richland County, South Caro...    2602         3026
# Census Tract 104.08, Richland County, South Car...   10408         4439
# Census Tract 206.05, Lexington County, South Ca...   20605         2457
# Census Tract 211.06, Lexington County, South Ca...   21106         2825
# Census Tract 205.08, Lexington County, South Ca...   20508         2051
# Census Tract 203, Lexington County, South Carol...   20300         3949
# Census Tract 205.11, Lexington County, South Ca...   20511         3552
# Census Tract 202.01, Lexington County, South Ca...   20201         2864
# Census Tract 206.01, Lexington County, South Ca...   20601         4384
# Census Tract 207.03, Lexington County, South Ca...   20703         4547
# Census Tract 105.02, Richland County, South Car...   10502         1211
# Census Tract 106, Richland County, South Caroli...   10600         4160
# Census Tract 107.02, Richland County, South Car...   10702         3823
# Census Tract 107.03, Richland County, South Car...   10703         3272
# Census Tract 112.01, Richland County, South Car...   11201         1938
# Census Tract 114.04, Richland County, South Car...   11404         9196
# Census Tract 116.04, Richland County, South Car...   11604         5645
# Census Tract 120, Richland County, South Caroli...   12000         5437
# Census Tract 210.17, Lexington County, South Ca...   21017         8580
# Census Tract 210.09, Lexington County, South Ca...   21009        11606
# Census Tract 210.14, Lexington County, South Ca...   21014         7318
# Census Tract 104.03, Richland County, South Car...   10403         3709
# Census Tract 3, Richland County, South Carolina...     300         2855
# Census Tract 11, Richland County, South Carolin...    1100         3530
# Census Tract 12, Richland County, South Carolin...    1200         1852
# Census Tract 16, Richland County, South Carolin...    1600         1522
# Census Tract 103.06, Richland County, South Car...   10306        12031
# Census Tract 112.02, Richland County, South Car...   11202         3456
# Census Tract 9, Richland County, South Carolina...     900         2411
# Census Tract 102, Richland County, South Caroli...   10200         5427
# Census Tract 13, Richland County, South Carolin...    1300         2024
# Census Tract 213.05, Lexington County, South Ca...   21305         3261
# Census Tract 213.06, Lexington County, South Ca...   21306         3721
# Census Tract 213.07, Lexington County, South Ca...   21307         1896
# Census Tract 213.08, Lexington County, South Ca...   21308         4480
# Census Tract 214.03, Lexington County, South Ca...   21403         2480
# Census Tract 214.04, Lexington County, South Ca...   21404         3233
# Census Tract 9801, Lexington County, South Caro...  980100            0
# Census Tract 26.04, Richland County, South Caro...    2604         1527
# Census Tract 26.03, Richland County, South Caro...    2603         3779
# Census Tract 29, Richland County, South Carolin...    2900         3790
# Census Tract 30, Richland County, South Carolin...    3000         2627
# Census Tract 207.05, Lexington County, South Ca...   20705         3584
# Census Tract 207.08, Lexington County, South Ca...   20708         2575
# Census Tract 207.06, Lexington County, South Ca...   20706         3433
# Census Tract 207.07, Lexington County, South Ca...   20707         3359
# Census Tract 208.01, Lexington County, South Ca...   20801         1437
# Census Tract 208.02, Lexington County, South Ca...   20802         2592
# Census Tract 208.03, Lexington County, South Ca...   20803         2993
# Census Tract 208.04, Lexington County, South Ca...   20804         2963
# Census Tract 208.05, Lexington County, South Ca...   20805         5541
# Census Tract 209.03, Lexington County, South Ca...   20903         5428
# Census Tract 101.03, Richland County, South Car...   10103        21490
# Census Tract 101.04, Richland County, South Car...   10104         4781
# Census Tract 103.08, Richland County, South Car...   10308         5724
# Census Tract 103.09, Richland County, South Car...   10309         9542
# Census Tract 104.10, Richland County, South Car...   10410         4083
# Census Tract 104.11, Richland County, South Car...   10411         3666
# Census Tract 104.12, Richland County, South Car...   10412         3011
# Census Tract 104.13, Richland County, South Car...   10413         2162
# Census Tract 108.05, Richland County, South Car...   10805         2698
# Census Tract 108.06, Richland County, South Car...   10806         1054
# Census Tract 114.11, Richland County, South Car...   11411         4068
# Census Tract 114.12, Richland County, South Car...   11412         4982
# Census Tract 114.13, Richland County, South Car...   11413         8466
# Census Tract 114.14, Richland County, South Car...   11414         5668
# Census Tract 114.15, Richland County, South Car...   11415        12487
# Census Tract 114.16, Richland County, South Car...   11416        14051
# Census Tract 114.17, Richland County, South Car...   11417         8508
# Census Tract 114.18, Richland County, South Car...   11418         4099
# Census Tract 114.19, Richland County, South Car...   11419         4307
# Census Tract 115.01, Richland County, South Car...   11501        11709
# Census Tract 115.02, Richland County, South Car...   11502         3271
# Census Tract 116.07, Richland County, South Car...   11607         4082
# Census Tract 116.08, Richland County, South Car...   11608         6298
# Census Tract 9801, Richland County, South Carol...  980100          266
# Census Tract 31, Richland County, South Carolin...    3100         1304
# Census Tract 22, Richland County, South Carolin...    2200         1135
# Census Tract 103.05, Richland County, South Car...   10305         7209
# Census Tract 119.02, Richland County, South Car...   11902         5337
# Census Tract 111.02, Richland County, South Car...   11102         4088
# Census Tract 113.05, Richland County, South Car...   11305         5597
# Census Tract 24, Richland County, South Carolin...    2400         3676
# Census Tract 28, Richland County, South Carolin...    2800         6527
# Census Tract 117.02, Richland County, South Car...   11702         3844
# Census Tract 2, Richland County, South Carolina...     200         1620
# Census Tract 23, Richland County, South Carolin...    2300         2180
# Census Tract 101.02, Richland County, South Car...   10102         9657
# Census Tract 103.04, Richland County, South Car...   10304         7624
# Census Tract 110, Richland County, South Caroli...   11000         1826
# Census Tract 105.01, Richland County, South Car...   10501         1932
# Census Tract 111.01, Richland County, South Car...   11101         3254
# Census Tract 103.07, Richland County, South Car...   10307        11767
# Census Tract 107.01, Richland County, South Car...   10701         2833
# Census Tract 108.04, Richland County, South Car...   10804         2489
# Census Tract 119.01, Richland County, South Car...   11901         8539
# Census Tract 109, Richland County, South Caroli...   10900         2922
# Census Tract 113.03, Richland County, South Car...   11303         5006
# Census Tract 114.07, Richland County, South Car...   11407         4539
# Census Tract 116.06, Richland County, South Car...   11606         5057
# Census Tract 117.01, Richland County, South Car...   11701         4841
# Census Tract 1, Richland County, South Carolina...     100         2244
# Census Tract 5, Richland County, South Carolina...     500         2220
# Census Tract 6, Richland County, South Carolina...     600         2110
# Census Tract 10, Richland County, South Carolin...    1000         3236
# Census Tract 21, Richland County, South Carolin...    2100         2866
# Census Tract 209.04, Lexington County, South Ca...   20904         2827
# Census Tract 209.05, Lexington County, South Ca...   20905         3597
# Census Tract 209.07, Lexington County, South Ca...   20907         7954
# Census Tract 209.08, Lexington County, South Ca...   20908         3551
# Census Tract 210.19, Lexington County, South Ca...   21019         1866
# Census Tract 210.20, Lexington County, South Ca...   21020         4327
# Census Tract 210.21, Lexington County, South Ca...   21021         1877
# Census Tract 209.06, Lexington County, South Ca...   20906         3763
# Census Tract 210.22, Lexington County, South Ca...   21022         5820
# Census Tract 210.23, Lexington County, South Ca...   21023         2871
# Census Tract 210.24, Lexington County, South Ca...   21024         6484
# Census Tract 210.25, Lexington County, South Ca...   21025         3968
# Census Tract 210.26, Lexington County, South Ca...   21026         5018
# Census Tract 210.27, Lexington County, South Ca...   21027         4475
# Census Tract 210.28, Lexington County, South Ca...   21028         3250
# Census Tract 210.29, Lexington County, South Ca...   21029         4084
# Census Tract 210.30, Lexington County, South Ca...   21030         4974
# Census Tract 210.31, Lexington County, South Ca...   21031         3953
# Census Tract 210.32, Lexington County, South Ca...   21032         3940
# Census Tract 210.33, Lexington County, South Ca...   21033         4944
# Census Tract 210.34, Lexington County, South Ca...   21034         4879
# Census Tract 7, Richland County, South Carolina...     700         1778
# Census Tract 211.09, Lexington County, South Ca...   21109         3307
# Census Tract 211.10, Lexington County, South Ca...   21110         2979
# Census Tract 211.11, Lexington County, South Ca...   21111         2578
# Census Tract 211.12, Lexington County, South Ca...   21112         2831
# Census Tract 211.13, Lexington County, South Ca...   21113         3407
# Census Tract 211.14, Lexington County, South Ca...   21114         3648
# Census Tract 211.15, Lexington County, South Ca...   21115         2466
# Census Tract 211.16, Lexington County, South Ca...   21116         3124
# Census Tract 212.03, Lexington County, South Ca...   21203         6244
# Census Tract 212.04, Lexington County, South Ca...   21204         4370
# Census Tract 212.05, Lexington County, South Ca...   21205         3225
# Census Tract 212.06, Lexington County, South Ca...   21206         3326
# Census Tract 213.03, Lexington County, South Ca...   21303         4309
# Census Tract 213.04, Lexington County, South Ca...   21304         3720
# Census Tract 27, Richland County, South Carolin...    2700         2861
# Census Tract 104.07, Richland County, South Car...   10407         3933
# Census Tract 104.09, Richland County, South Car...   10409         1800
# Census Tract 108.03, Richland County, South Car...   10803         2195
# Census Tract 113.01, Richland County, South Car...   11301         5937
# Census Tract 113.04, Richland County, South Car...   11304         4932
# Census Tract 116.03, Richland County, South Car...   11603         5835
# Census Tract 118, Richland County, South Caroli...   11800         5804
# Census Tract 4, Richland County, South Carolina...     400         1900
# Census Tract 202.02, Lexington County, South Ca...   20202         2392
# Census Tract 210.18, Lexington County, South Ca...   21018         4741
# Census Tract 214.02, Lexington County, South Ca...   21402         3726
# Census Tract 206.04, Lexington County, South Ca...   20604         3424
# Census Tract 205.06, Lexington County, South Ca...   20506         5208
# Census Tract 205.09, Lexington County, South Ca...   20509         3404
# Census Tract 205.10, Lexington County, South Ca...   20510         4598
# Census Tract 206.02, Lexington County, South Ca...   20602         4346
# Census Tract 201, Lexington County, South Carol...   20100         2745
# Census Tract 205.05, Lexington County, South Ca...   20505         3936
# Census Tract 205.07, Lexington County, South Ca...   20507         6693
#
#                                                     B06012_001E  B06012_002E  \
# Census Tract 25, Richland County, South Carolin...         3695          280
# Census Tract 26.02, Richland County, South Caro...         3011          516
# Census Tract 104.08, Richland County, South Car...          200          183
# Census Tract 206.05, Lexington County, South Ca...         2457          223
# Census Tract 211.06, Lexington County, South Ca...         2825          103
# Census Tract 205.08, Lexington County, South Ca...         1959           51
# Census Tract 203, Lexington County, South Carol...         3863         1139
# Census Tract 205.11, Lexington County, South Ca...         3244          305
# Census Tract 202.01, Lexington County, South Ca...         2864          752
# Census Tract 206.01, Lexington County, South Ca...         4384          478
# Census Tract 207.03, Lexington County, South Ca...         4547          951
# Census Tract 105.02, Richland County, South Car...         1211          591
# Census Tract 106, Richland County, South Caroli...         4124         1626
# Census Tract 107.02, Richland County, South Car...         3823         1004
# Census Tract 107.03, Richland County, South Car...         3272         1343
# Census Tract 112.01, Richland County, South Car...         1938           53
# Census Tract 114.04, Richland County, South Car...         9152         1746
# Census Tract 116.04, Richland County, South Car...         5582          311
# Census Tract 120, Richland County, South Caroli...         5399         1090
# Census Tract 210.17, Lexington County, South Ca...         8580          962
# Census Tract 210.09, Lexington County, South Ca...        11526         1008
# Census Tract 210.14, Lexington County, South Ca...         7318          160
# Census Tract 104.03, Richland County, South Car...         3702          528
# Census Tract 3, Richland County, South Carolina...         2855         1337
# Census Tract 11, Richland County, South Carolin...         3270          491
# Census Tract 12, Richland County, South Carolin...         1801           29
# Census Tract 16, Richland County, South Carolin...         1522          427
# Census Tract 103.06, Richland County, South Car...        11846          661
# Census Tract 112.02, Richland County, South Car...         3456          353
# Census Tract 9, Richland County, South Carolina...         2411         1396
# Census Tract 102, Richland County, South Caroli...         5422          795
# Census Tract 13, Richland County, South Carolin...         1578          509
# Census Tract 213.05, Lexington County, South Ca...         3128          699
# Census Tract 213.06, Lexington County, South Ca...         3709          380
# Census Tract 213.07, Lexington County, South Ca...         1896          380
# Census Tract 213.08, Lexington County, South Ca...         4469          689
# Census Tract 214.03, Lexington County, South Ca...         2465          515
# Census Tract 214.04, Lexington County, South Ca...         3233          349
# Census Tract 9801, Lexington County, South Caro...            0            0
# Census Tract 26.04, Richland County, South Caro...         1510          363
# Census Tract 26.03, Richland County, South Caro...         3779         1116
# Census Tract 29, Richland County, South Carolin...         1050          410
# Census Tract 30, Richland County, South Carolin...         1614          650
# Census Tract 207.05, Lexington County, South Ca...         3568          894
# Census Tract 207.08, Lexington County, South Ca...         2575          532
# Census Tract 207.06, Lexington County, South Ca...         3433         1016
# Census Tract 207.07, Lexington County, South Ca...         3346          709
# Census Tract 208.01, Lexington County, South Ca...         1437          304
# Census Tract 208.02, Lexington County, South Ca...         2578          526
# Census Tract 208.03, Lexington County, South Ca...         2952          700
# Census Tract 208.04, Lexington County, South Ca...         2963          746
# Census Tract 208.05, Lexington County, South Ca...         5427         1263
# Census Tract 209.03, Lexington County, South Ca...         5398         1195
# Census Tract 101.03, Richland County, South Car...        21461         1267
# Census Tract 101.04, Richland County, South Car...         4781          357
# Census Tract 103.08, Richland County, South Car...         5724          459
# Census Tract 103.09, Richland County, South Car...         9526          291
# Census Tract 104.10, Richland County, South Car...         4054         1101
# Census Tract 104.11, Richland County, South Car...         3666         1220
# Census Tract 104.12, Richland County, South Car...         3011          580
# Census Tract 104.13, Richland County, South Car...         1956          285
# Census Tract 108.05, Richland County, South Car...         2608          519
# Census Tract 108.06, Richland County, South Car...          181          148
# Census Tract 114.11, Richland County, South Car...         4068          531
# Census Tract 114.12, Richland County, South Car...         4965          846
# Census Tract 114.13, Richland County, South Car...         8386          637
# Census Tract 114.14, Richland County, South Car...         5575          450
# Census Tract 114.15, Richland County, South Car...        12464          931
# Census Tract 114.16, Richland County, South Car...        14051         1296
# Census Tract 114.17, Richland County, South Car...         8458          472
# Census Tract 114.18, Richland County, South Car...         4099          302
# Census Tract 114.19, Richland County, South Car...         4307          705
# Census Tract 115.01, Richland County, South Car...            0            0
# Census Tract 115.02, Richland County, South Car...         2740            5
# Census Tract 116.07, Richland County, South Car...         4049          997
# Census Tract 116.08, Richland County, South Car...         6298          963
# Census Tract 9801, Richland County, South Carol...            9            4
# Census Tract 31, Richland County, South Carolin...         1254          669
# Census Tract 22, Richland County, South Carolin...         1135          183
# Census Tract 103.05, Richland County, South Car...         7209          392
# Census Tract 119.02, Richland County, South Car...         5301          618
# Census Tract 111.02, Richland County, South Car...         4049          271
# Census Tract 113.05, Richland County, South Car...         5477         1085
# Census Tract 24, Richland County, South Carolin...         3676          309
# Census Tract 28, Richland County, South Carolin...         3724         2274
# Census Tract 117.02, Richland County, South Car...         2953          884
# Census Tract 2, Richland County, South Carolina...         1606          429
# Census Tract 23, Richland County, South Carolin...         2169          104
# Census Tract 101.02, Richland County, South Car...         9641         1641
# Census Tract 103.04, Richland County, South Car...         7578         1592
# Census Tract 110, Richland County, South Caroli...         1792          340
# Census Tract 105.01, Richland County, South Car...         1632          261
# Census Tract 111.01, Richland County, South Car...         3135          462
# Census Tract 103.07, Richland County, South Car...        11767          369
# Census Tract 107.01, Richland County, South Car...         2833          545
# Census Tract 108.04, Richland County, South Car...         2448          829
# Census Tract 119.01, Richland County, South Car...         8468          758
# Census Tract 109, Richland County, South Caroli...         2821         1451
# Census Tract 113.03, Richland County, South Car...         4920          475
# Census Tract 114.07, Richland County, South Car...         4530          482
# Census Tract 116.06, Richland County, South Car...         5035          481
# Census Tract 117.01, Richland County, South Car...         4841         2974
# Census Tract 1, Richland County, South Carolina...         1903          529
# Census Tract 5, Richland County, South Carolina...         2210         1007
# Census Tract 6, Richland County, South Carolina...         2110          311
# Census Tract 10, Richland County, South Carolin...         1525          668
# Census Tract 21, Richland County, South Carolin...         2854          794
# Census Tract 209.04, Lexington County, South Ca...         2745          337
# Census Tract 209.05, Lexington County, South Ca...         3563         1027
# Census Tract 209.07, Lexington County, South Ca...         7929         1380
# Census Tract 209.08, Lexington County, South Ca...         3530          226
# Census Tract 210.19, Lexington County, South Ca...         1854           71
# Census Tract 210.20, Lexington County, South Ca...         4306          328
# Census Tract 210.21, Lexington County, South Ca...         1877           93
# Census Tract 209.06, Lexington County, South Ca...         3735         1052
# Census Tract 210.22, Lexington County, South Ca...         5804           69
# Census Tract 210.23, Lexington County, South Ca...         2848          175
# Census Tract 210.24, Lexington County, South Ca...         6459          298
# Census Tract 210.25, Lexington County, South Ca...         3968          346
# Census Tract 210.26, Lexington County, South Ca...         5018          175
# Census Tract 210.27, Lexington County, South Ca...         4053          237
# Census Tract 210.28, Lexington County, South Ca...         3250          392
# Census Tract 210.29, Lexington County, South Ca...         2668          400
# Census Tract 210.30, Lexington County, South Ca...         4862          458
# Census Tract 210.31, Lexington County, South Ca...         3953          504
# Census Tract 210.32, Lexington County, South Ca...         3940           43
# Census Tract 210.33, Lexington County, South Ca...         4944          138
# Census Tract 210.34, Lexington County, South Ca...         4824          631
# Census Tract 7, Richland County, South Carolina...         1705          328
# Census Tract 211.09, Lexington County, South Ca...         3307          129
# Census Tract 211.10, Lexington County, South Ca...         2979          107
# Census Tract 211.11, Lexington County, South Ca...         2578          195
# Census Tract 211.12, Lexington County, South Ca...         2822            0
# Census Tract 211.13, Lexington County, South Ca...         3407          503
# Census Tract 211.14, Lexington County, South Ca...         3603          340
# Census Tract 211.15, Lexington County, South Ca...         2466          265
# Census Tract 211.16, Lexington County, South Ca...         3120          150
# Census Tract 212.03, Lexington County, South Ca...         6233           85
# Census Tract 212.04, Lexington County, South Ca...         4348          352
# Census Tract 212.05, Lexington County, South Ca...         3216          147
# Census Tract 212.06, Lexington County, South Ca...         3326          115
# Census Tract 213.03, Lexington County, South Ca...         4309          460
# Census Tract 213.04, Lexington County, South Ca...         3720          331
# Census Tract 27, Richland County, South Carolin...         2699          604
# Census Tract 104.07, Richland County, South Car...         3933         1031
# Census Tract 104.09, Richland County, South Car...         1800          330
# Census Tract 108.03, Richland County, South Car...         2195          826
# Census Tract 113.01, Richland County, South Car...         5916          678
# Census Tract 113.04, Richland County, South Car...         4927         1167
# Census Tract 116.03, Richland County, South Car...         5835          358
# Census Tract 118, Richland County, South Caroli...         5804          757
# Census Tract 4, Richland County, South Carolina...         1887          428
# Census Tract 202.02, Lexington County, South Ca...         2365          641
# Census Tract 210.18, Lexington County, South Ca...         4741          964
# Census Tract 214.02, Lexington County, South Ca...         3721          755
# Census Tract 206.04, Lexington County, South Ca...         3424          284
# Census Tract 205.06, Lexington County, South Ca...         4968          353
# Census Tract 205.09, Lexington County, South Ca...         3376          688
# Census Tract 205.10, Lexington County, South Ca...         4598          442
# Census Tract 206.02, Lexington County, South Ca...         4327          604
# Census Tract 201, Lexington County, South Carol...         2745          296
# Census Tract 205.05, Lexington County, South Ca...         3936          892
# Census Tract 205.07, Lexington County, South Ca...         6688         1427
#
#                                                     B06012_003E  B06012_004E
# Census Tract 25, Richland County, South Carolin...          135         3280
# Census Tract 26.02, Richland County, South Caro...          248         2247
# Census Tract 104.08, Richland County, South Car...           13            4
# Census Tract 206.05, Lexington County, South Ca...          218         2016
# Census Tract 211.06, Lexington County, South Ca...          273         2449
# Census Tract 205.08, Lexington County, South Ca...           75         1833
# Census Tract 203, Lexington County, South Carol...          685         2039
# Census Tract 205.11, Lexington County, South Ca...          647         2292
# Census Tract 202.01, Lexington County, South Ca...          373         1739
# Census Tract 206.01, Lexington County, South Ca...          566         3340
# Census Tract 207.03, Lexington County, South Ca...          521         3075
# Census Tract 105.02, Richland County, South Car...          136          484
# Census Tract 106, Richland County, South Caroli...          418         2080
# Census Tract 107.02, Richland County, South Car...          453         2366
# Census Tract 107.03, Richland County, South Car...          369         1560
# Census Tract 112.01, Richland County, South Car...          151         1734
# Census Tract 114.04, Richland County, South Car...          896         6510
# Census Tract 116.04, Richland County, South Car...          139         5132
# Census Tract 120, Richland County, South Caroli...          458         3851
# Census Tract 210.17, Lexington County, South Ca...          975         6643
# Census Tract 210.09, Lexington County, South Ca...         1042         9476
# Census Tract 210.14, Lexington County, South Ca...          246         6912
# Census Tract 104.03, Richland County, South Car...          298         2876
# Census Tract 3, Richland County, South Carolina...          346         1172
# Census Tract 11, Richland County, South Carolin...          452         2327
# Census Tract 12, Richland County, South Carolin...           31         1741
# Census Tract 16, Richland County, South Carolin...          106          989
# Census Tract 103.06, Richland County, South Car...          470        10715
# Census Tract 112.02, Richland County, South Car...          160         2943
# Census Tract 9, Richland County, South Carolina...          249          766
# Census Tract 102, Richland County, South Caroli...          622         4005
# Census Tract 13, Richland County, South Carolin...          318          751
# Census Tract 213.05, Lexington County, South Ca...          468         1961
# Census Tract 213.06, Lexington County, South Ca...          295         3034
# Census Tract 213.07, Lexington County, South Ca...          269         1247
# Census Tract 213.08, Lexington County, South Ca...          412         3368
# Census Tract 214.03, Lexington County, South Ca...          339         1611
# Census Tract 214.04, Lexington County, South Ca...          166         2718
# Census Tract 9801, Lexington County, South Caro...            0            0
# Census Tract 26.04, Richland County, South Caro...          229          918
# Census Tract 26.03, Richland County, South Caro...          532         2131
# Census Tract 29, Richland County, South Carolin...           49          591
# Census Tract 30, Richland County, South Carolin...          194          770
# Census Tract 207.05, Lexington County, South Ca...          476         2198
# Census Tract 207.08, Lexington County, South Ca...           98         1945
# Census Tract 207.06, Lexington County, South Ca...          242         2175
# Census Tract 207.07, Lexington County, South Ca...          121         2516
# Census Tract 208.01, Lexington County, South Ca...          100         1033
# Census Tract 208.02, Lexington County, South Ca...          235         1817
# Census Tract 208.03, Lexington County, South Ca...          386         1866
# Census Tract 208.04, Lexington County, South Ca...          610         1607
# Census Tract 208.05, Lexington County, South Ca...         1076         3088
# Census Tract 209.03, Lexington County, South Ca...          557         3646
# Census Tract 101.03, Richland County, South Car...         1020        19174
# Census Tract 101.04, Richland County, South Car...          394         4030
# Census Tract 103.08, Richland County, South Car...          262         5003
# Census Tract 103.09, Richland County, South Car...          504         8731
# Census Tract 104.10, Richland County, South Car...          758         2195
# Census Tract 104.11, Richland County, South Car...          477         1969
# Census Tract 104.12, Richland County, South Car...          351         2080
# Census Tract 104.13, Richland County, South Car...          519         1152
# Census Tract 108.05, Richland County, South Car...          744         1345
# Census Tract 108.06, Richland County, South Car...           25            8
# Census Tract 114.11, Richland County, South Car...          203         3334
# Census Tract 114.12, Richland County, South Car...          322         3797
# Census Tract 114.13, Richland County, South Car...          490         7259
# Census Tract 114.14, Richland County, South Car...          417         4708
# Census Tract 114.15, Richland County, South Car...          934        10599
# Census Tract 114.16, Richland County, South Car...         1174        11581
# Census Tract 114.17, Richland County, South Car...          471         7515
# Census Tract 114.18, Richland County, South Car...          480         3317
# Census Tract 114.19, Richland County, South Car...          262         3340
# Census Tract 115.01, Richland County, South Car...            0            0
# Census Tract 115.02, Richland County, South Car...          591         2144
# Census Tract 116.07, Richland County, South Car...          496         2556
# Census Tract 116.08, Richland County, South Car...          589         4746
# Census Tract 9801, Richland County, South Carol...            0            5
# Census Tract 31, Richland County, South Carolin...           90          495
# Census Tract 22, Richland County, South Carolin...           39          913
# Census Tract 103.05, Richland County, South Car...          856         5961
# Census Tract 119.02, Richland County, South Car...          648         4035
# Census Tract 111.02, Richland County, South Car...          181         3597
# Census Tract 113.05, Richland County, South Car...         1023         3369
# Census Tract 24, Richland County, South Carolin...          199         3168
# Census Tract 28, Richland County, South Carolin...          340         1110
# Census Tract 117.02, Richland County, South Car...          367         1702
# Census Tract 2, Richland County, South Carolina...          422          755
# Census Tract 23, Richland County, South Carolin...           30         2035
# Census Tract 101.02, Richland County, South Car...          334         7666
# Census Tract 103.04, Richland County, South Car...         1082         4904
# Census Tract 110, Richland County, South Caroli...          167         1285
# Census Tract 105.01, Richland County, South Car...          213         1158
# Census Tract 111.01, Richland County, South Car...          253         2420
# Census Tract 103.07, Richland County, South Car...          154        11244
# Census Tract 107.01, Richland County, South Car...          827         1461
# Census Tract 108.04, Richland County, South Car...          308         1311
# Census Tract 119.01, Richland County, South Car...          997         6713
# Census Tract 109, Richland County, South Caroli...          566          804
# Census Tract 113.03, Richland County, South Car...          481         3964
# Census Tract 114.07, Richland County, South Car...          577         3471
# Census Tract 116.06, Richland County, South Car...          644         3910
# Census Tract 117.01, Richland County, South Car...          789         1078
# Census Tract 1, Richland County, South Carolina...          351         1023
# Census Tract 5, Richland County, South Carolina...          417          786
# Census Tract 6, Richland County, South Carolina...          276         1523
# Census Tract 10, Richland County, South Carolin...          297          560
# Census Tract 21, Richland County, South Carolin...          130         1930
# Census Tract 209.04, Lexington County, South Ca...          127         2281
# Census Tract 209.05, Lexington County, South Ca...          332         2204
# Census Tract 209.07, Lexington County, South Ca...          497         6052
# Census Tract 209.08, Lexington County, South Ca...          262         3042
# Census Tract 210.19, Lexington County, South Ca...           78         1705
# Census Tract 210.20, Lexington County, South Ca...          333         3645
# Census Tract 210.21, Lexington County, South Ca...          131         1653
# Census Tract 209.06, Lexington County, South Ca...          272         2411
# Census Tract 210.22, Lexington County, South Ca...          551         5184
# Census Tract 210.23, Lexington County, South Ca...          210         2463
# Census Tract 210.24, Lexington County, South Ca...          106         6055
# Census Tract 210.25, Lexington County, South Ca...           88         3534
# Census Tract 210.26, Lexington County, South Ca...          274         4569
# Census Tract 210.27, Lexington County, South Ca...           46         3770
# Census Tract 210.28, Lexington County, South Ca...           97         2761
# Census Tract 210.29, Lexington County, South Ca...          330         1938
# Census Tract 210.30, Lexington County, South Ca...          211         4193
# Census Tract 210.31, Lexington County, South Ca...          148         3301
# Census Tract 210.32, Lexington County, South Ca...          132         3765
# Census Tract 210.33, Lexington County, South Ca...          521         4285
# Census Tract 210.34, Lexington County, South Ca...          350         3843
# Census Tract 7, Richland County, South Carolina...          235         1142
# Census Tract 211.09, Lexington County, South Ca...          364         2814
# Census Tract 211.10, Lexington County, South Ca...           95         2777
# Census Tract 211.11, Lexington County, South Ca...          201         2182
# Census Tract 211.12, Lexington County, South Ca...          331         2491
# Census Tract 211.13, Lexington County, South Ca...          191         2713
# Census Tract 211.14, Lexington County, South Ca...          103         3160
# Census Tract 211.15, Lexington County, South Ca...           20         2181
# Census Tract 211.16, Lexington County, South Ca...          100         2870
# Census Tract 212.03, Lexington County, South Ca...           83         6065
# Census Tract 212.04, Lexington County, South Ca...          283         3713
# Census Tract 212.05, Lexington County, South Ca...          135         2934
# Census Tract 212.06, Lexington County, South Ca...          142         3069
# Census Tract 213.03, Lexington County, South Ca...          115         3734
# Census Tract 213.04, Lexington County, South Ca...          402         2987
# Census Tract 27, Richland County, South Carolin...          330         1765
# Census Tract 104.07, Richland County, South Car...          460         2442
# Census Tract 104.09, Richland County, South Car...          330         1140
# Census Tract 108.03, Richland County, South Car...          228         1141
# Census Tract 113.01, Richland County, South Car...          100         5138
# Census Tract 113.04, Richland County, South Car...          495         3265
# Census Tract 116.03, Richland County, South Car...          357         5120
# Census Tract 118, Richland County, South Caroli...         1058         3989
# Census Tract 4, Richland County, South Carolina...          232         1227
# Census Tract 202.02, Lexington County, South Ca...          227         1497
# Census Tract 210.18, Lexington County, South Ca...          284         3493
# Census Tract 214.02, Lexington County, South Ca...          445         2521
# Census Tract 206.04, Lexington County, South Ca...          190         2950
# Census Tract 205.06, Lexington County, South Ca...          539         4076
# Census Tract 205.09, Lexington County, South Ca...          583         2105
# Census Tract 205.10, Lexington County, South Ca...          520         3636
# Census Tract 206.02, Lexington County, South Ca...          373         3350
# Census Tract 201, Lexington County, South Carol...          237         2212
# Census Tract 205.05, Lexington County, South Ca...          420         2624
# Census Tract 205.07, Lexington County, South Ca...          559         4702

# %% [markdown]
# ### (12) Vehicle Ownership Data
#
# A crucial factor of the USDA's Low-Income, Low-Access designation (modern, more descriptive version of the colloquial food desert) is vehicle ownership. This looks at the Census data for vehicle ownership by ZCTA.

# %%
# https://api.census.gov/data/2010/acs/acs5/variables.html
# B01003_001E - Estimate!!Total - TOTAL POPULATION
# API - https://api.census.gov/data/2016/acs/acs5?get=NAME,ZCTA,B01003_001E&for=zip+code+tabulation+area:*&in=state:12
years = [2016, 2017, 2018, 2019, 2020]
census_product = 'acs5'
fips_string = ','.join(state_fips_codes)
code_string = 'B08201_002E'
year_zcta_vehicle_dict = {}

for year in years:
    # API didn't seem to support the "in" query for specifying states
    if year == 2020:
        vehicle_table = censusdata.download(census_product, year,
           censusdata.censusgeo([
               ('zip%20code%20tabulation%20area', '*')
           ]),['ZCTA','B08201_001E','B08201_002E'])
    else:
        vehicle_table = censusdata.download(census_product, year,
           censusdata.censusgeo([
               ('state', fips_string),
               ('zip%20code%20tabulation%20area', '*')
           ]),['ZCTA','B08201_001E','B08201_002E'])
        
    zcta_vehicle_dict = {}
    for i, zcta in enumerate(list(vehicle_table.ZCTA)):
        zcta_vehicle_dict[zcta] = {
            "Total Households": vehicle_table.B08201_001E.iloc[i],
            "No Vehicle": vehicle_table.B08201_002E.iloc[i],
            "No Vehicle %": vehicle_table.B08201_002E.iloc[i] / vehicle_table.B08201_001E.iloc[i] * 100
        }
    year_zcta_vehicle_dict[year] = zcta_vehicle_dict
    print("Finished processing {0} {1}".format(census_product, year))
# Out:
# /var/folders/1m/gs67qnm13_zdcfgmdqmjy_sh0000gp/T/ipykernel_54145/2848875190.py:29: RuntimeWarning: invalid value encountered in long_scalars
#   "No Vehicle %": vehicle_table.B08201_002E.iloc[i] / vehicle_table.B08201_001E.iloc[i] * 100
# Finished processing acs5 2016
# Finished processing acs5 2017
# Finished processing acs5 2018
# Finished processing acs5 2019
# Finished processing acs5 2020

# %%
for year in years: print(year_zcta_vehicle_dict[year][29203])
# Out:
# {'Total Households': 14767, 'No Vehicle': 1912, 'No Vehicle %': 12.947788988961875}
# {'Total Households': 14934, 'No Vehicle': 2164, 'No Vehicle %': 14.49042453461899}
# {'Total Households': 15033, 'No Vehicle': 2242, 'No Vehicle %': 14.913856183063926}
# {'Total Households': 15348, 'No Vehicle': 2365, 'No Vehicle %': 15.409173833724262}
# {'Total Households': 15589, 'No Vehicle': 2265, 'No Vehicle %': 14.529475912502404}
